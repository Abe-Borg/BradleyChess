# %%
import game_settings
import pandas as pd

# %%
chess_data = pd.read_pickle(game_settings.chess_games_filepath_part_1, compression = 'zip')

# %%
chess_data.head(1)
# Out:
#         PlyCount  W1  B1    W2    B2   W3   B3   W4   B4   W5   B5  W6    B6  \
# Game 1        41  e4  d5  exd5  Qxd5  Nc3  Qd8  Bc4  Nf6  Nf3  Bg4  h3  Bxf3
#
#           W7  B7    W8    B8   W9   B9   W10  B10   W11   B11 W12  B12   W13  \
# Game 1  Qxf3  e6  Qxb7  Nbd7  Nb5  Rc8  Nxa7  Nb6  Nxc8  Nxc8  d4  Nd6  Bb5+
#
#          B13    W14  B14 W15   B15  W16  B16  W17  B17   W18  B18  W19   B19  \
# Game 1  Nxb5  Qxb5+  Nd7  d5  exd5  Be3  Bd6  Rd1  Qf6  Rxd5  Qg6  Bf4  Bxf4
#
#           W20  B20   W21 B21 W22 B22 W23 B23 W24 B24 W25 B25 W26 B26 W27 B27  \
# Game 1  Qxd7+  Kf8  Qd8#
#
#        W28 B28 W29 B29 W30 B30 W31 B31 W32 B32 W33 B33 W34 B34 W35 B35 W36  \
# Game 1
#
#        B36 W37 B37 W38 B38 W39 B39 W40 B40 W41 B41 W42 B42 W43 B43 W44 B44  \
# Game 1
#
#        W45 B45 W46 B46 W47 B47 W48 B48 W49 B49 W50 B50 W51 B51 W52 B52 W53  \
# Game 1
#
#        B53 W54 B54 W55 B55 W56 B56 W57 B57 W58 B58 W59 B59 W60 B60 W61 B61  \
# Game 1
#
#        W62 B62 W63 B63 W64 B64 W65 B65 W66 B66 W67 B67 W68 B68 W69 B69 W70  \
# Game 1
#
#        B70 W71 B71 W72 B72 W73 B73 W74 B74 W75 B75 W76 B76 W77 B77 W78 B78  \
# Game 1
#
#        W79 B79 W80 B80 W81 B81 W82 B82 W83 B83 W84 B84 W85 B85 W86 B86 W87  \
# Game 1
#
#        B87 W88 B88 W89 B89 W90 B90 W91 B91 W92 B92 W93 B93 W94 B94 W95 B95  \
# Game 1
#
#        W96 B96 W97 B97 W98 B98 W99 B99 W100 B100 W101 B101 W102 B102 W103  \
# Game 1
#
#        B103 W104 B104 W105 B105 W106 B106 W107 B107 W108 B108 W109 B109 W110  \
# Game 1
#
#        B110 W111 B111 W112 B112 W113 B113 W114 B114 W115 B115 W116 B116 W117  \
# Game 1
#
#        B117 W118 B118 W119 B119 W120 B120 W121 B121 W122 B122 W123 B123 W124  \
# Game 1
#
#        B124 W125 B125 W126 B126 W127 B127 W128 B128 W129 B129 W130 B130 W131  \
# Game 1
#
#        B131 W132 B132 W133 B133 W134 B134 W135 B135 W136 B136 W137 B137 W138  \
# Game 1
#
#        B138 W139 B139 W140 B140 W141 B141 W142 B142 W143 B143 W144 B144 W145  \
# Game 1
#
#        B145 W146 B146 W147 B147 W148 B148 W149 B149 W150 B150 W151 B151 W152  \
# Game 1
#
#        B152 W153 B153 W154 B154 W155 B155 W156 B156 W157 B157 W158 B158 W159  \
# Game 1
#
#        B159 W160 B160 W161 B161 W162 B162 W163 B163 W164 B164 W165 B165 W166  \
# Game 1
#
#        B166 W167 B167 W168 Result
# Game 1                        1-0

# %%
chess_data.shape
# Out:
# (3951, 200)
