# %%
import game_settings
import pandas as pd

# %%
chess_data = pd.read_pickle(game_settings.chess_games_filepath_part_2, compression = 'zip')

# %%
chess_data.head(1)
# Out:
#         PlyCount  W1  B1   W2   B2  W3  B3   W4   B4   W5   B5  W6    B6   W7  \
# Game 1        78  d4  d5  Nf3  Nf6  c4  e6  Nc3  Be7  Bg5  O-O  e3  Nbd7  Rc1
#
#         B7   W8  B8    W9    B9  W10 B10  W11  B11  W12  B12  W13   B13   W14  \
# Game 1  c6  Qc2  a6  cxd5  exd5  Bd3  h6  Bh4  Re8  O-O  Ne4  Bg3  Nxg3  hxg3
#
#         B14  W15  B15  W16  B16  W17   B17   W18  B18  W19  B19   W20   B20  \
# Game 1  Nf6  Na4  Bd6  Nc5  Qe7  Bf5  Bxc5  Bxc8  Bd6  Bf5  Ne4  Bxe4  dxe4
#
#         W21   B21  W22 B22  W23 B23   W24   B24  W25   B25   W26  B26   W27  \
# Game 1  Nd2  Rad8  Qb3  h5  Nc4  h4  Nxd6  Rxd6  Rc5  hxg3  fxg3  Qd7  Rcf5
#
#         B27   W28 B28  W29  B29   W30   B30  W31  B31 W32  B32  W33 B33  W34  \
# Game 1  Re7  R1f4  g6  Ra5  Rd5  Rxd5  Qxd5  Qb6  Rd7  b3  Kg7  Qb4  a5  Qc3
#
#         B34  W35  B35  W36  B36 W37  B37  W38  B38  W39  B39 W40 B40 W41 B41  \
# Game 1  Rd6  Qc2  Re6  Qf2  Re7  g4  Qg5  Qc2  Qd5  Qf2  Qg5
#
# ...

# %%
chess_data.shape
# Out:
# (3951, 200)
