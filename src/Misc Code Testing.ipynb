# %%
import game_settings
import pandas as pd

# %%
chess_data = pd.read_pickle(game_settings.chess_games_filepath_part_32, compression = 'zip')

# %%
chess_data.shape
# Out:
# (98215, 379)

# %%
chess_data.head()
# Out:
#         PlyCount  W1   B1   W2   B2    W3    B3   W4    B4    W5     B5    W6  \
# Game 1        60  e4   c5  Nc3   d6    g3    g6  Bg2   Bg7   Nf3    Nc6   O-O
# Game 2        71  e4   c6   d4   d5  exd5  cxd5  Bd3   Nc6    c3    Nf6   Bf4
# Game 3        77  d4   e6   c4  Nf6    g3  Bb4+  Nd2    c5    a3  Bxd2+  Qxd2
# Game 4        57  e4   c6   d4   d5  exd5  cxd5  Bd3   Nc6    c3    Nf6   Bf4
# Game 5        78  d4  Nf6   c4   c5    d5    e6  Nc3  exd5  cxd5     d6    e4
#
#           B6    W7   B7   W8   B8    W9    B9   W10   B10   W11   B11   W12  \
# Game 1   Nf6    d3  O-O   h3  Rb8    a4    a6   Ne2    b5  axb5  axb5    c3
# Game 2   Bg4   Qb3  Qc8  Nd2  Bh5  Ngf3   Bg6  Bxg6  hxg6   O-O    e6  Rae1
# Game 3  cxd4  Qxd4  Nc6  Qh4  Qb6   Nf3   Na5    b4   Nb3   Be3   Qa6   Ra2
# Game 4   Bg4   Qb3  Qc8  Nd2   e6  Ngf3  Bxf3  Nxf3   Be7   O-O   O-O  Rae1
# Game 5    g6   Nf3  Bg7  Be2  O-O   O-O   Re8   Nd2    a6    a4  Nbd7   Qc2
#
# ...

# %%
chess_data = pd.read_pickle(game_settings.chess_games_filepath_part_32, compression = 'zip')
